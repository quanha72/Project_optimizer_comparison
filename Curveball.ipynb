# %%
# %cd /content/drive/MyDrive/Quan_task
# Out:
# /content/drive/MyDrive/Quan_task

# %%
# !mkdir optimizer_task
# %cd optimizer_task
# Out:
# /content/drive/MyDrive/Quan_task/optimizer_task

# %%
# !git clone https://github.com/quanha72/CurveBall_optimizer
# Out:
# Cloning into 'CurveBall_optimizer'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 85 (delta 37), reused 84 (delta 36), pack-reused 0
# Unpacking objects: 100% (85/85), done.

# %%
# !pip install overboard
# Out:
# ...
#      |████████████████████████████████| 56 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 824 kB 8.1 MB/s
# ...
#      |████████████████████████████████| 133 kB 74.8 MB/s
# ...
#      |████████████████████████████████| 8.3 MB 77.6 MB/s
# ...
#      |████████████████████████████████| 317 kB 76.0 MB/s
# ...
#      |████████████████████████████████| 59.9 MB 1.2 MB/s
# ...

# %%
from overboard import Logger

# %%
# %cd /content/drive/MyDrive/Quan_task/optimizer_task/CurveBall_optimizer/examples
# !python cifar.py -epochs 25
# Out:
# Streaming output truncated to the last 5000 lines.
# ep 14 train loss: 0.696 accuracy: 0.763 time: 0.0176
# ep 14 train loss: 0.696 accuracy: 0.762 time: 0.0176
# ep 14 train loss: 0.695 accuracy: 0.763 time: 0.0176
# ep 14 train loss: 0.694 accuracy: 0.763 time: 0.0176
# ep 14 train loss: 0.694 accuracy: 0.763 time: 0.0177
# ep 14 train loss: 0.694 accuracy: 0.763 time: 0.0176
# ep 14 train loss: 0.694 accuracy: 0.763 time: 0.0176
# ep 14 train loss: 0.694 accuracy: 0.763 time: 0.0176
# ep 14 train loss: 0.693 accuracy: 0.763 time: 0.0176
# ep 14 train loss: 0.692 accuracy: 0.763 time: 0.0176
# ep 14 train loss: 0.693 accuracy: 0.763 time: 0.0176
# ep 14 train loss: 0.694 accuracy: 0.762 time: 0.0176
# ep 14 train loss: 0.694 accuracy: 0.762 time: 0.0176
# ep 14 train loss: 0.694 accuracy: 0.763 time: 0.0176
# ep 14 train loss: 0.695 accuracy: 0.763 time: 0.0176
# ep 14 train loss: 0.694 accuracy: 0.763 time: 0.0176
# ep 14 train loss: 0.693 accuracy: 0.763 time: 0.0176
# ...

# %%
def plot(df, key, smooth=None, **kwargs):
    df = df[df[key].notna()]
    if smooth:
        df[key] = df[key].rolling(smooth).mean()
    df.plot('i_itr', key, **kwargs)

# %%
import pandas as pd
data = pd.read_csv('/content/data/cifar-experiments/BasicNetBN/curveball/test/2021-12-24_13-36-48_962414/stats.csv')

# %%
data
# Out:
#                                 time  train.loss  ...  val.accuracy  val.time
# 0   2021-12-24 13:37:04.902662+00:00    1.573860  ...      0.539953  0.002106
# 1   2021-12-24 13:37:20.652179+00:00    1.221368  ...      0.616199  0.001850
# 2   2021-12-24 13:37:36.692365+00:00    1.073345  ...      0.663766  0.001848
# 3   2021-12-24 13:37:52.520883+00:00    0.981644  ...      0.688192  0.001924
# 4   2021-12-24 13:38:08.558396+00:00    0.910877  ...      0.671578  0.002061
# 5   2021-12-24 13:38:24.663932+00:00    0.867418  ...      0.707872  0.001844
# 6   2021-12-24 13:38:40.640760+00:00    0.830529  ...      0.723991  0.001954
# 7   2021-12-24 13:38:56.535528+00:00    0.791830  ...      0.724288  0.001837
# 8   2021-12-24 13:39:12.450332+00:00    0.768900  ...      0.709157  0.001900
# 9   2021-12-24 13:39:28.718907+00:00    0.749883  ...      0.733584  0.001873
# 10  2021-12-24 13:39:44.778953+00:00    0.727481  ...      0.745352  0.001813
# ...

# %% [markdown]
# ###Resnet-50

# %%
# %cd /content/drive/MyDrive/Quan_task/optimizer_task
# Out:
# /content/drive/MyDrive/Quan_task/optimizer_task

# %%
# %cd curve_ballresnet
# Out:
# /content/drive/MyDrive/Quan_task/optimizer_task/curve_ballresnet

# %%
# !git clone https://github.com/quanha72/CurveBall_optimizer
# Out:
# Cloning into 'CurveBall_optimizer'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 85 (delta 37), reused 84 (delta 36), pack-reused 0
# Unpacking objects: 100% (85/85), done.

# %%
# %cd /content/drive/MyDrive/Quan_task/optimizer_task/curve_ballresnet/CurveBall_optimizer/examples
# !python cifar.py -epochs 10 -model 'ResNet50' -lr 1e-3
# Out:
# /content/drive/MyDrive/Quan_task/optimizer_task/curve_ballresnet/CurveBall_optimizer/examples
# Files already downloaded and verified
# Files already downloaded and verified
# /content/drive/MyDrive/Quan_task/optimizer_task/curve_ballresnet/CurveBall_optimizer/curveball.py:70: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1050.)
#   dz.data.add_(lambd, z)
# ep 0 train loss: 2.41 accuracy: 0.0703
# ep 0 train loss: 2.41 accuracy: 0.102
# ep 0 train loss: 2.38 accuracy: 0.109
# ep 0 train loss: 2.37 accuracy: 0.115 time: 2.13
# ep 0 train loss: 2.38 accuracy: 0.116 time: 2.13
# ep 0 train loss: 2.39 accuracy: 0.116 time: 2.15
# ep 0 train loss: 2.41 accuracy: 0.126 time: 2.15
# ep 0 train loss: 2.44 accuracy: 0.13 time: 2.15
# ep 0 train loss: 2.45 accuracy: 0.122 time: 2.14
# ...

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/Quan_task/optimizer_task/curve_ballresnet/CurveBall_optimizer/examples/data/cifar-experiments/ResNet50/curveball/test/2021-12-24_17-39-19_552961/stats.csv')
data
# Out:
#                                time  train.loss  ...  val.accuracy  val.time
# 0  2021-12-24 17:53:28.143570+00:00    2.805161  ...      0.416238  0.066516
# 1  2021-12-24 18:07:33.219132+00:00    1.386393  ...      0.573081  0.061402
# 2  2021-12-24 18:21:36.939331+00:00    1.033294  ...      0.660206  0.061403
# 3  2021-12-24 18:35:40.568608+00:00    0.830948  ...      0.708366  0.061401
# 4  2021-12-24 18:49:44.079133+00:00    0.697636  ...      0.725376  0.061403
# 5  2021-12-24 19:03:47.638135+00:00    0.587709  ...      0.788964  0.061426
# 6  2021-12-24 19:17:51.119780+00:00    0.496281  ...      0.782338  0.061466
# 7  2021-12-24 19:31:54.573258+00:00    0.433949  ...      0.819620  0.061402
# 8  2021-12-24 19:45:58.018919+00:00    0.383559  ...      0.834553  0.061427
# 9  2021-12-24 20:00:01.466609+00:00    0.338481  ...      0.853244  0.061475
#
# [10 rows x 7 columns]
